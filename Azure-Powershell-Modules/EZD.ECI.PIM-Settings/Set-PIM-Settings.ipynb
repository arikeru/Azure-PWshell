# %%
# NOTE: WE ONLY NEED THE POLICY ID OF ALL THE ROLES TO WORK WITH. EACH ROLE HAS A UNIQUE POLICY ID
# ALL SETTINGS TAKE IN A BOOLEAN PARAMETER OF $TRUE OR $FALSE

# %%
Connect-MgGraph -Scopes "Domain.ReadWrite.All", "Policy.ReadWrite.Authorization"
Connect-MgGraph -Scopes "RoleManagement.ReadWrite.Directory"

# %%
Import-Module Microsoft.Graph.Identity.DirectoryManagement

Get-ChildItem -Path "C:\Users\Personal\Desktop\TEST-PIM\EZD.ECI.Common\Public" -Filter *.ps1 | Unblock-File
Get-ChildItem -Path "C:\Users\Personal\Desktop\TEST-PIM\EZD.ECI.PIM-Settings\Public" -Filter *.ps1 | Unblock-File

# %%
 # Example cmdlet to update PIM settings (replace with actual cmdlet)
Set-MgPrivilegedRoleSetting -RoleId "GlobalAdministrator" -RequireApproval $true

# %%
# Example cmdlet to configure alerts (replace with actual cmdlet)
Set-MgAlertConfiguration -AlertType "HighlyPrivilegedRoleAssignment" -Enabled $true

# %%
 # Example cmdlet to configure alerts (replace with actual cmdlet)
 Set-MgAlertConfiguration -AlertType "GlobalAdminActivation" -Enabled $true

# %%
 # Example cmdlet to configure alerts (replace with actual cmdlet)
 Set-MgAlertConfiguration -AlertType "OtherRoleActivation" -Enabled $true

# %%
#Connect
Connect-MgGraph -Scopes "RoleManagement.ReadWrite.Directory"

# %%
# get global admin role and its def id. Roletemplate id is the roledefinition id

Get-MgDirectoryRole -Filter "displayName eq 'Global Administrator'" | Select-Object Id, DisplayName, RoleTemplateId

# %%
# get policy assignment for global admin role 

Get-MgPolicyRoleManagementPolicyAssignment -Filter "scopeId eq '/' and  RoleDefinitionId eq '62e90394-69f5-4237-9190-012177145e10' and scopeType eq 'Directory'"

# %%
# Get policy id for a role 

Get-MgPolicyRoleManagementPolicy -Filter "scopeId eq '/' and  RoleDefinitionId eq '62e90394-69f5-4237-9190-012177145e10' and scopeType eq 'Directory'"

# %%
#get details of global admin roles specific policy

 $policyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338"
 Get-MgPolicyRoleManagementPolicy -UnifiedRoleManagementPolicyId $policyId | FL


# Description           : Directory
# DisplayName           : Directory
# EffectiveRules        :
# Id                    : Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338
# IsOrganizationDefault : False
# LastModifiedBy        : Microsoft.Graph.PowerShell.Models.MicrosoftGraphIdentity
# LastModifiedDateTime  :
# Rules                 :
# ScopeId               : /
# ScopeType             : Directory
# AdditionalProperties  : {[@odata.context, https://graph.microsoft.com/v1.0/$metadata#policies/roleManagementPolicies/$entity]}

# %%
# Get rule settings in this policy

Get-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $policyId | FL


# Id                   : Expiration_Admin_Eligibility
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyExpirationRule], [isExpirationRequired, False], [maximumDuration, P365D]}

# Id                   : Enablement_Admin_Eligibility
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyEnablementRule], [enabledRules, System.Object[]]}

# Id                   : Notification_Admin_Admin_Eligibility
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Admin], [notificationLevel, All]...}

# Id                   : Notification_Requestor_Admin_Eligibility
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Requestor], [notificationLevel, All]...}

# Id                   : Notification_Approver_Admin_Eligibility
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Approver], [notificationLevel, All]...}

# Id                   : Expiration_Admin_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyExpirationRule], [isExpirationRequired, False], [maximumDuration, P180D]}

# Id                   : Enablement_Admin_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyEnablementRule], [enabledRules, System.Object[]]}

# Id                   : Notification_Admin_Admin_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Admin], [notificationLevel, All]...}

# Id                   : Notification_Requestor_Admin_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Requestor], [notificationLevel, All]...}

# Id                   : Notification_Approver_Admin_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Approver], [notificationLevel, All]...}

# Id                   : Expiration_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyExpirationRule], [isExpirationRequired, True], [maximumDuration, PT8H]}

# Id                   : Enablement_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyEnablementRule], [enabledRules, System.Object[]]}

# Id                   : Approval_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyApprovalRule], [setting, System.Collections.Generic.Dictionary`2[System.String,System.Object]]}

# Id                   : AuthenticationContext_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyAuthenticationContextRule], [isEnabled, False]}

# Id                   : Notification_Admin_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Admin], [notificationLevel, All]...}

# Id                   : Notification_Requestor_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Requestor], [notificationLevel, All]...}

# Id                   : Notification_Approver_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Approver], [notificationLevel, All]...}

# %%
# get the settings of the approval end user assignment rule in the policy

 $policyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338"
 $approvalRule = Get-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $policyId | Where-Object { $_.Id -eq 'Approval_EndUser_Assignment' }
 $approvalRule | Format-List *


# Id                   : Approval_EndUser_Assignment
# Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
# AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyApprovalRule], [setting, System.Collections.Generic.Dictionary`2[System.String,System.Object]]}



 $approvalSettings = $approvalRule.AdditionalProperties.setting
 $approvalSettings

# Key                                                                                               Value
# ---                                                                                               -----
# isApprovalRequired                                                                                False
# isApprovalRequiredForExtension                                                                    False
# isRequestorJustificationRequired                                                                   True
# approvalMode                                                                                SingleStage
# approvalStages                   {System.Collections.Generic.Dictionary`2[System.String,System.Object]}

# %%
# Update the isApprovalRequired setting to True------ General structure format

 $unifiedRoleManagementPolicyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338"
 $unifiedRoleManagementPolicyRuleId = "Approval_EndUser_Assignment"

 $params = @{
     "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyApprovalRule"
     id = "Approval_EndUser_Assignment"
     target = @{
         "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyRuleTarget"
         caller = "EndUser"
         operations = @(
            "Activate"
         )
         level = "Activation"
         inheritableSettings = @()
         enforcedSettings = @()
     }
     setting = @{
         "@odata.type" = "#microsoft.graph.approvalSettings"
         isApprovalRequired = $true
         isApprovalRequiredForExtension = $false
         isRequestorJustificationRequired = $true
         approvalMode = "SingleStage"
         approvalStages = @(
             @{
                 "@odata.type" = "#microsoft.graph.unifiedApprovalStage"
                 approvalStageTimeOutInDays = 7  # Set an appropriate timeout
                 isApproverJustificationRequired = $true
                 escalationTimeInMinutes = 1440  # For example, 1 day
                 primaryApprovers = @(
                     @{
                         "@odata.type" = "#microsoft.graph.singleUser"
                         userId = "10a08e2e-3ea2-4ce0-80cb-d5fdd4b05ea6"
                     },
                     @{
                         "@odata.type" = "#microsoft.graph.groupMembers"
                        groupId = "14f2746d-7d6f-4ac6-acd8-8cac318b041b"
                    }
                 )
                 isEscalationEnabled = $false
             }
         )
     }
 }

Update-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $unifiedRoleManagementPolicyId -UnifiedRoleManagementPolicyRuleId $unifiedRoleManagementPolicyRuleId -BodyParameter $params

#results after checking


# Key                                                                                               Value
# ---                                                                                               -----
# isApprovalRequired                                                                                 True
# isApprovalRequiredForExtension                                                                    False
# isRequestorJustificationRequired                                                                   True
# approvalMode                                                                                SingleStage
# approvalStages                   {System.Collections.Generic.Dictionary`2[System.String,System.Object]}

# %%
# refined format to take out parameters we dont need in params
# applies only to rule 4 required y global admin role only.

 $unifiedRoleManagementPolicyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338"
 $unifiedRoleManagementPolicyRuleId = "Approval_EndUser_Assignment"

 $params = @{
     "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyApprovalRule"
     id = "Approval_EndUser_Assignment"
     target = @{
         "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyRuleTarget"
         caller = "EndUser"
         operations = @(
            "Activate"
         )
         level = "Activation"
     }
     setting = @{
         "@odata.type" = "#microsoft.graph.approvalSettings"
         isApprovalRequired = $true
         approvalStages = @()
     }
 }

Update-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $unifiedRoleManagementPolicyId -UnifiedRoleManagementPolicyRuleId $unifiedRoleManagementPolicyRuleId -BodyParameter $params

#results after checking


# Key                                                                                               Value
# ---                                                                                               -----
# isApprovalRequired                                                                                 True
# isApprovalRequiredForExtension                                                                    False
# isRequestorJustificationRequired                                                                   True
# approvalMode                                                                                SingleStage
# approvalStages                   {System.Collections.Generic.Dictionary`2[System.String,System.Object]}

# %%
# get the settings of the notification admin enduser assignment rule in the policy

 $policyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338"
 $notificationadminenduserassignmentrule = Get-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $policyId | Where-Object { $_.Id -eq 'Notification_Admin_EndUser_Assignment' }
 $notificationadminenduserassignmentrule | Format-List *

 Id                   : Notification_Admin_EndUser_Assignment
Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Admin], [notificationLevel, All]...}


  $notificationsettings = $notificationadminenduserassignmentrule.AdditionalProperties
  $notificationsettings

Key                        Value
---                        -----
@odata.type                #microsoft.graph.unifiedRoleManagementPolicyNotificationRule
notificationType           Email
recipientType              Admin
notificationLevel          All
isDefaultRecipientsEnabled False
notificationRecipients     {}

$notificationadminenduserassignmentrule | ConvertTo-Json -Depth 10
{
    "Id":  "Notification_Admin_EndUser_Assignment",
    "Target":  {
                   "Caller":  "EndUser",
                   "EnforcedSettings":  [

                                        ],
                   "InheritableSettings":  [

                                           ],
                   "Level":  "Assignment",
                   "Operations":  [
                                      "all"
                                  ],
                   "TargetObjects":  null
               },
    "AdditionalProperties":  {
                                 "@odata.type":  "#microsoft.graph.unifiedRoleManagementPolicyNotificationRule",
                                 "notificationType":  "Email",
                                 "recipientType":  "Admin",
                                 "notificationLevel":  "All",
                                 "isDefaultRecipientsEnabled":  false,
                                 "notificationRecipients":  [

                                                            ]
                             }
}

# %%
# refined format to take out parameters we dont need in params
#Applies to rule 15  Notification_Admin_EndUser_Assignment required by global admin ROLE and all other highly priv roles

 $unifiedRoleManagementPolicyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_e526683e-043f-49cb-b284-eb80a8ef8338"
 $unifiedRoleManagementPolicyRuleId = "Notification_Admin_EndUser_Assignment"

 $params = @{
    "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyNotificationRule"
    id = "Notification_Admin_EndUser_Assignment"
    target = @{
        "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyRuleTarget"
        caller = "EndUser"
        operations = @(
            "Activate"
        )
        level = "Activation"
    }
    notificationType = "Email"
    recipientType = "Admin"
    notificationLevel = "All"
    isDefaultRecipientsEnabled = $true
    notificationRecipients = @()
}

Update-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $unifiedRoleManagementPolicyId -UnifiedRoleManagementPolicyRuleId $unifiedRoleManagementPolicyRuleId -BodyParameter $params

# %%
# working with next High Prev role "Privileged Role Administrator"

Get-MgDirectoryRole -Filter "displayName eq 'Privileged Role Administrator'" | Select-Object Id, DisplayName, RoleTemplateId

Id                                   DisplayName                   RoleTemplateId
--                                   -----------                   --------------
e4b9448c-dc2f-44c3-8630-dad404913b12 Privileged Role Administrator e8611ab8-c189-46e8-94e1-60213ab1f814



Get-MgPolicyRoleManagementPolicyAssignment -Filter "scopeId eq '/' and  RoleDefinitionId eq 'e8611ab8-c189-46e8-94e1-60213ab1f814' and scopeType eq 'Directory'"

Id                                                                                                                       PolicyId                                                                            RoleDefinitionId                     ScopeId ScopeType
--                                                                                                                       --------                                                                            ----------------                     ------- ---------
Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_abd8c68c-2770-4d0e-bbd5-a653972dd9fe_e8611ab8-c189-46e8-94e1-60213ab1f814 Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_abd8c68c-2770-4d0e-bbd5-a653972dd9fe e8611ab8-c189-46e8-94e1-60213ab1f814 /       Directory

# %%
$policyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_abd8c68c-2770-4d0e-bbd5-a653972dd9fe"
Get-MgPolicyRoleManagementPolicy -UnifiedRoleManagementPolicyId $policyId | FL
Get-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $policyId | FL

$notificationadminadmineligibility = Get-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $policyId | Where-Object { $_.Id -eq 'Notification_Admin_Admin_Eligibility' }
$notificationadminadmineligibility | Format-List *


Id                   : Notification_Admin_Admin_Eligibility
Target               : Microsoft.Graph.PowerShell.Models.MicrosoftGraphUnifiedRoleManagementPolicyRuleTarget
AdditionalProperties : {[@odata.type, #microsoft.graph.unifiedRoleManagementPolicyNotificationRule], [notificationType, Email], [recipientType, Admin], [notificationLevel, All]...}



$notificationeligibilitysettings = $notificationadminadmineligibility.AdditionalProperties
$notificationeligibilitysettings

Key                        Value
---                        -----
@odata.type                #microsoft.graph.unifiedRoleManagementPolicyNotificationRule
notificationType           Email
recipientType              Admin
notificationLevel          All
isDefaultRecipientsEnabled True
notificationRecipients     {}

# %%
# refined format to take out parameters we dont need in params for Notification_Admin_Admin_Eligibility
#applies for rules 9, 12 Notification_Admin_Admin_Eligibility and Notification_Admin_Admin_Assignment for all other Highly priv roles

 $unifiedRoleManagementPolicyId = "Directory_e1d41e97-df11-48ba-8a96-e7d2ad4d17f9_abd8c68c-2770-4d0e-bbd5-a653972dd9fe"
 $unifiedRoleManagementPolicyRuleId = "Notification_Admin_Admin_Eligibility"

 $params = @{
    "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyNotificationRule"
    id = "Notification_Admin_Admin_Eligibility"
    target = @{
        "@odata.type" = "#microsoft.graph.unifiedRoleManagementPolicyRuleTarget"
        caller = "All"
        operations = @(
            "Add"
        )
        level = "Eligibilty"
    }
    notificationType = "Email"
    recipientType = "Admin"
    notificationLevel = "All"
    isDefaultRecipientsEnabled = $true
    notificationRecipients = @()
}

Update-MgPolicyRoleManagementPolicyRule -UnifiedRoleManagementPolicyId $unifiedRoleManagementPolicyId -UnifiedRoleManagementPolicyRuleId $unifiedRoleManagementPolicyRuleId -BodyParameter $params

# %%
# ROLE IDs 

Global Administrator = "62e90394-69f5-4237-9190-012177145e10"
Privileged Role Administrator = "e8611ab8-c189-46e8-94e1-60213ab1f814"
User Administrator = "fe930be7-5e62-47db-91af-98c3a49a38b1"
SharePoint Administrator = "f28a1f50-f6e7-4571-818b-6a12f2af6b6c"
Exchange Administrator = "29232cdf-9323-42fd-ade2-1d097af3e4de"
Hybrid Identity Administrator = "8ac3fc64-6eca-42ea-9e69-59f4c7b60eb2"
Application Administrator = "9b895d92-2cd3-44c7-9d02-a6ac2d5ea5c3"
Cloud Application Administrator = "158c047a-c907-4556-b7ef-446551a6b5f7"

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $false -PIM_SETTINGS $true
====================================================================================================
Current: Drift Detection Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
Unknown Rule Type: 
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type:
Unknown Rule Type: 
====================================================================================================
DRIFT SUMMARY:
All PIM settings are configured as desired. No drift detected.
====================================================================================================
------------------- CURRENT STATE OF PIM SETTINGS --------------------
====================================================================================================
Role: Global Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
Role: Privileged Role Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
Role: User Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
Role: SharePoint Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
Role: Exchange Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
Role: Hybrid Identity Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
Role: Application Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
Role: Cloud Application Administrator
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type: 
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type:
  Unknown Rule Type: 
====================================================================================================
NO DRIFT DETECTED: CURRENT PIM SETTINGS ALIGN WITH DESIRED CONFIGURATIONS
====================================================================================================
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE

Name                           Value
----                           -----
ExitCode                       0
ExitLogs                       No drift detected.

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $false -PIM_SETTINGS $true                       
====================================================================================================
Current: Drift Detection Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role Global Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role Global Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role Global Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role Global Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role Privileged Role Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role Privileged Role Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role Privileged Role Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role Privileged Role Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role User Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role User Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role User Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role User Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role SharePoint Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role SharePoint Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role SharePoint Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role SharePoint Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role Exchange Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role Exchange Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role Exchange Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role Exchange Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role Hybrid Identity Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role Hybrid Identity Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role Hybrid Identity Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role Hybrid Identity Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role Application Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role Application Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role Application Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role Application Administrator.
  Current: , Desired: True
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
Drift in Notification_Admin_Admin_Eligibility for role Cloud Application Administrator.
  Current: , Desired: True
Drift in Notification_Admin_Admin_Assignment for role Cloud Application Administrator.
  Current: , Desired: True
Drift in Approval_EndUser_Assignment for role Cloud Application Administrator.
  Current: , Desired: True
Drift in Notification_Admin_EndUser_Assignment for role Cloud Application Administrator.
  Current: , Desired: True
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
Global Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
Global Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
Global Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
Privileged Role Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
Privileged Role Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
Privileged Role Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
Privileged Role Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
User Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
User Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
User Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
User Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
SharePoint Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
SharePoint Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
SharePoint Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
SharePoint Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
Exchange Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
Exchange Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
Exchange Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
Exchange Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
Hybrid Identity Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
Hybrid Identity Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
Hybrid Identity Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
Hybrid Identity Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
Application Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
Application Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
Application Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
Application Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
Cloud Application Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True
Cloud Application Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=True
Cloud Application Administrator | Approval_EndUser_Assignment | Current= -> Desired=True
Cloud Application Administrator | Notification_Admin_EndUser_Assignment | Current= -> Desired=True
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE

Name                           Value
----                           -----
ExitCode                       2
ExitLogs                       {Global Administrator | Notification_Admin_Admin_Eligibility | Current= -> Desired=True, Global Administrator | Notification_Admin_Admin_Assignment | Current= -> Desired=T…

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $false -PIM_SETTINGS $true
====================================================================================================
Current: Drift Detection Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Global Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Global Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Global Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Global Administrator is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Privileged Role Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Privileged Role Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Privileged Role Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Privileged Role Administrator is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role User Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role User Administrator is as desired.
Drift in Approval_EndUser_Assignment for role User Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role User Administrator is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role SharePoint Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role SharePoint Administrator is as desired.
Drift in Approval_EndUser_Assignment for role SharePoint Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role SharePoint Administrator is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Exchange Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Exchange Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Exchange Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Exchange Administrator is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Hybrid Identity Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Hybrid Identity Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Hybrid Identity Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Hybrid Identity Administrator is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Application Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Application Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Application Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Application Administrator is as desired.
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Application Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Application Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Application Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Application Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role Application Administrator is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Cloud Application Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Cloud Application Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Cloud Application Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Cloud Application Administrator is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Drift in Approval_EndUser_Assignment for role Cloud Application Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Cloud Application Administrator is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
DRIFT SUMMARY:
Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Privileged Role Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
User Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
SharePoint Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Exchange Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Hybrid Identity Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Application Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Cloud Application Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
User Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
SharePoint Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Exchange Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Hybrid Identity Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Application Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Cloud Application Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE
Application Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
Cloud Application Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE

Name                           Value

Name                           Value

Name                           Value
----                           -----
ExitCode                       2
ExitLogs                       {Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True, Privileged Role Administrator | Approval_EndUser_Assignment | Current=False -> Desired…

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $false -PIM_SETTINGS $true
====================================================================================================       
Current: Drift Detection Run
====================================================================================================       
Compiling current state and calculating drift...
====================================================================================================       
Evaluating role: Global Administrator
====================================================================================================       
Notification_Admin_Admin_Eligibility rule for role Global Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Global Administrator is as desired.
Drift in Approval_EndUser_Assignment for role Global Administrator.
  Current: False, Desired: True
Notification_Admin_EndUser_Assignment rule for role Global Administrator is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Privileged Role Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Privileged Role Administrator is as desired.      
Notification_Admin_EndUser_Assignment rule for role Privileged Role Administrator is as desired.    
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role User Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role User Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role User Administrator is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role SharePoint Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role SharePoint Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role SharePoint Administrator is as desired.
====================================================================================================       
Evaluating role: Exchange Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Exchange Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Exchange Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role Exchange Administrator is as desired.
====================================================================================================       
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Notification_Admin_Admin_Eligibility rule for role Hybrid Identity Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Hybrid Identity Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role Hybrid Identity Administrator is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================       
Notification_Admin_Admin_Eligibility rule for role Application Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Application Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role Application Administrator is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================       
Notification_Admin_Admin_Eligibility rule for role Cloud Application Administrator is as desired.
Notification_Admin_Admin_Assignment rule for role Cloud Application Administrator is as desired.
Notification_Admin_EndUser_Assignment rule for role Cloud Application Administrator is as desired.
====================================================================================================       
DRIFT SUMMARY:
Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE

Name                           Value
----                           -----
ExitCode                       2
ExitLogs                       {Global Administrator | Approval_EndUser_Assignment | Current=False -> Des…

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $false -PIM_SETTINGS $true
====================================================================================================
Current: Drift Detection Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Global Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Global Administrator role is as desired.
The current Approval setting for Approval_EndUser_Assignment rule is False for role Global Administrator.
The Approval setting of the Approval_EndUser_Assignment policy rule for Global Administrator is not configured as desired.
Its Approval requirement setting should be set to True
The rule to send notifications when eligible members activate the Global Administrator role is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Privileged Role Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Privileged Role Administrator role is as desired.
The rule to send notifications when eligible members activate the Privileged Role Administrator role is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the User Administrator role is as desired.
The rule to send notifications when members are assigned as active to the User Administrator role is as desired.
The rule to send notifications when eligible members activate the User Administrator role is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the SharePoint Administrator role is as desired.
The rule to send notifications when members are assigned as active to the SharePoint Administrator role is as desired.
The rule to send notifications when eligible members activate the SharePoint Administrator role is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Exchange Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Exchange Administrator role is as desired.
The rule to send notifications when eligible members activate the Exchange Administrator role is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when eligible members activate the Hybrid Identity Administrator role is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Application Administrator role is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Cloud Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Cloud Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Cloud Application Administrator role is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
====================================================================================================
------------------- CURRENT STATE OF PASSWORD POLICIES --------------------
====================================================================================================
------------- Current State of Password expiration policy Before Changes --------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Approval_EndUser_Assignment: Approval Configuration: False
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: User Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
====================================================================================================
DRIFT DETECTED: THE CURRENT STATE DOES NOT ALIGN WITH THE DESIRED STATE FOR SOME RULES OF SOME HIGHLY PRIVILEGED ROLES
====================================================================================================
THIS IS A DRIFT DETECTION RUN. NO CHANGES WILL BE MADE

Name                           Value
----                           -----
ExitLogs                       {Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True}
ExitCode                       2

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $true -PIM_SETTINGS $true
====================================================================================================
Current: Deployment Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Global Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Global Administrator role is as desired.
The current Approval setting for Approval_EndUser_Assignment rule is False for role Global Administrator.
The Approval setting of the Approval_EndUser_Assignment policy rule for Global Administrator is not configured as desired.
Its Approval requirement setting should be set to True
The rule to send notifications when eligible members activate the Global Administrator role is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Privileged Role Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Privileged Role Administrator role is as desired.
The rule to send notifications when eligible members activate the Privileged Role Administrator role is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the User Administrator role is as desired.
The rule to send notifications when members are assigned as active to the User Administrator role is as desired.
The rule to send notifications when eligible members activate the User Administrator role is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the SharePoint Administrator role is as desired.
The rule to send notifications when members are assigned as active to the SharePoint Administrator role is as desired.
The rule to send notifications when eligible members activate the SharePoint Administrator role is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Exchange Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Exchange Administrator role is as desired.
The rule to send notifications when eligible members activate the Exchange Administrator role is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when eligible members activate the Hybrid Identity Administrator role is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Application Administrator role is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Cloud Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Cloud Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Cloud Application Administrator role is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Approval_EndUser_Assignment | Current=False -> Desired=True
====================================================================================================
------------------- CURRENT STATE OF PASSWORD POLICIES --------------------
====================================================================================================
------------- Current State of Password expiration policy Before Changes --------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Approval_EndUser_Assignment: Approval Configuration: False
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: User Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
====================================================================================================
DRIFT DETECTED: THE CURRENT STATE DOES NOT ALIGN WITH THE DESIRED STATE FOR SOME RULES OF SOME HIGHLY PRIVILEGED ROLES
====================================================================================================
UPDATING PIM SETTINGS TO MATCH THE DESIRED STATE FOR THE 4 TARGET RULES.
Processing rule 'Approval_EndUser_Assignment' for role 'Global Administrator'.

Successfully updated rule Approval_EndUser_Assignment for role Global Administrator.
====================================================================================================
Performing post-configuration drift detection.
====================================================================================================
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Global Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Global Administrator role is as desired.
The rule to require Approval upon activation for role Global Administrator is as desired.
The rule to send notifications when eligible members activate the Global Administrator role is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Privileged Role Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Privileged Role Administrator role is as desired.
The rule to send notifications when eligible members activate the Privileged Role Administrator role is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the User Administrator role is as desired.
The rule to send notifications when members are assigned as active to the User Administrator role is as desired.
The rule to send notifications when eligible members activate the User Administrator role is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the SharePoint Administrator role is as desired.
The rule to send notifications when members are assigned as active to the SharePoint Administrator role is as desired.
The rule to send notifications when eligible members activate the SharePoint Administrator role is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Exchange Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Exchange Administrator role is as desired.
The rule to send notifications when eligible members activate the Exchange Administrator role is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when eligible members activate the Hybrid Identity Administrator role is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Application Administrator role is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Cloud Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Cloud Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Cloud Application Administrator role is as desired.
====================================================================================================
DRIFT SUMMARY:
Cloud Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
====================================================================================================
------------------- CURRENT STATE OF PASSWORD POLICIES --------------------
====================================================================================================
------------- Current State of Password expiration policy After Changes ---------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Approval_EndUser_Assignment: Approval Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: User Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
====================================================================================================
NO DRIFT DETECTED: THE CURRENT STATE ALIGNS WITH THE DESIRED STATE FOR ALL HIGHLY PRIVILEGED ROLES
====================================================================================================
PIM SETTINGS ARE CONFIGURED AS DESIRED. THE CHANGE WAS SUCCESSFUL.
Id
--
Approval_EndUser_Assignment

Key   : ExitLogs
Value : Change was successful.
Name  : ExitLogs


Key   : ExitCode
Value : 3
Name  : ExitCode

# %%
PS C:\Users\Personal\Desktop\TEST-PIM> Set-PIMSettings -ExecuteChange $true -PIM_SETTINGS $true
====================================================================================================
Current: Deployment Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Global Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Global Administrator role is as desired.
The rule to require Approval upon activation for role Global Administrator is as desired.
The rule to send notifications when eligible members activate the Global Administrator role is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Privileged Role Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Privileged Role Administrator role is as desired.
The rule to send notifications when eligible members activate the Privileged Role Administrator role is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the User Administrator role is as desired.
The rule to send notifications when members are assigned as active to the User Administrator role is as desired.
The rule to send notifications when eligible members activate the User Administrator role is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the SharePoint Administrator role is as desired.
The rule to send notifications when members are assigned as active to the SharePoint Administrator role is as desired.
The rule to send notifications when eligible members activate the SharePoint Administrator role is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Exchange Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Exchange Administrator role is as desired.
The rule to send notifications when eligible members activate the Exchange Administrator role is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Hybrid Identity Administrator role is as desired.
The rule to send notifications when eligible members activate the Hybrid Identity Administrator role is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Application Administrator role is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
The rule to send notifications when members are assigned as eligible to the Cloud Application Administrator role is as desired.
The rule to send notifications when members are assigned as active to the Cloud Application Administrator role is as desired.
The rule to send notifications when eligible members activate the Cloud Application Administrator role is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Global Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Global Administrator | Approval_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Global Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Exchange Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Exchange Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Exchange Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
====================================================================================================
------------------- CURRENT STATE OF PASSWORD POLICIES --------------------
====================================================================================================
------------- Current State of Password expiration policy Before Changes --------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Approval_EndUser_Assignment: Approval Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: User Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Alert Configuration: True
Notification_Admin_Admin_Assignment: Alert Configuration: True
Notification_Admin_EndUser_Assignment: Alert Configuration: True
====================================================================================================
NO DRIFT DETECTED: THE CURRENT STATE ALIGNS WITH THE DESIRED STATE FOR ALL HIGHLY PRIVILEGED ROLES
====================================================================================================
NO CHANGE IS REQUIRED. SETTINGS ARE ALREADY CONFIGURED AS DESIRED.

Name                           Value
----                           -----
ExitLogs                       No drift detected.
ExitCode                       0

# %%
Set-PIMSettings -ExecuteChange $true -APPROVAL_AND_DEFAULTRECIPIENT_SETTINGS $true -AdditionalNotificationRecipients @("sezai@rnkondagmail.onmicrosoft.com")
====================================================================================================
Current: Deployment Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the Global Administrator role is as desired.
The rule to require Approval upon activation for role Global Administrator is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Global Administrator role is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Privileged Role Administrator role is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the User Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the User Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the User Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the User Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the User Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the User Administrator role is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the SharePoint Administrator role is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Exchange Administrator role is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Hybrid Identity Administrator role is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Application Administrator role is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
Sending notifications to default recipients for this rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to additional recipients  for this rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to default recipients for this rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to additional recipients for this rule when eligible members activate the Cloud Application Administrator role is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Global Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Global Administrator | Approval_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Global Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Exchange Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Exchange Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Exchange Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
====================================================================================================
------------------- CURRENT STATE OF PIM SETTINGS FOR HIGHLY PRIVILEGED ROLES --------------------
====================================================================================================
------------- Current State of Pim Settings For Highly Privileged Roles Before Changes --------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Approval_EndUser_Assignment: Approval Configuration: True
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: User Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
====================================================================================================
NO DRIFT DETECTED: THE CURRENT STATE ALIGNS WITH THE DESIRED STATE FOR ALL HIGHLY PRIVILEGED ROLES
====================================================================================================
NO CHANGE IS REQUIRED. SETTINGS ARE ALREADY CONFIGURED AS DESIRED.

Name                           Value
----                           -----
ExitCode                       0
ExitLogs                       No drift detected.

# %%
Set-PIMSettings -ExecuteChange $true -APPROVAL_AND_DEFAULTRECIPIENT_SETTINGS $true -AdditionalNotificationRecipients @()
====================================================================================================
Current: Deployment Run
====================================================================================================
Compiling current state and calculating drift...
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Global Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role Global Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for Global Administrator is not configured as 
desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Global Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Global Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for Global Administrator is not configured as desired.
Its Additional Recipients should be set to: []
The rule to require Approval upon activation for role Global Administrator is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Global Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Global Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for Global Administrator is not configured as 
desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Privileged Role Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role Privileged Role Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for Privileged Role Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Privileged Role Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Privileged Role Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for Privileged Role Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Privileged Role Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Privileged Role Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for Privileged Role Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the User Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role User Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for User Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the User Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role User Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for User Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
User Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role User Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for User Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the SharePoint Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role SharePoint Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for SharePoint Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the SharePoint Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role SharePoint Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for SharePoint Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
SharePoint Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role SharePoint Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for SharePoint Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Exchange Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role Exchange Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for Exchange Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Exchange Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Exchange Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for Exchange Administrator is not configured as 
desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Exchange Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Exchange Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for Exchange Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Hybrid Identity Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role Hybrid Identity Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for Hybrid Identity Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Hybrid Identity Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Hybrid Identity Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for Hybrid Identity Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Hybrid Identity Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Hybrid Identity Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for Hybrid Identity Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Application Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role Application Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for Application Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Application Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Application Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for Application Administrator is not configured 
as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Application Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Application Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for Application Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Cloud Application Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Eligibility rule is : [sezai@rnkondagmail.onmicrosoft.com] for 
role Cloud Application Administrator
The Additional Recipients for NNotification_Admin_Admin_Eligibility policy rule for Cloud Application Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Cloud Application Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_Admin_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Cloud Application Administrator
The Additional Recipients for Notification_Admin_Admin_Assignment policy rule for Cloud Application Administrator is not configured as desired.
Its Additional Recipients should be set to: []
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Cloud Application Administrator role is as desired.
The Current Additional Recipients for Notification_Admin_EndUser_Assignment rule is : [sezai@rnkondagmail.onmicrosoft.com] for role Cloud Application Administrator
The Additional Recipients for Notification_Admin_EndUser_Assignment policy rule for Cloud Application Administrator is not configured as desired.
Its Additional Recipients should be set to: []
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Global Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Global Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Privileged Role Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Privileged Role Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Privileged Role Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
User Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
User Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
User Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
SharePoint Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
SharePoint Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
SharePoint Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Exchange Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Exchange Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Exchange Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Hybrid Identity Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Hybrid Identity Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Hybrid Identity Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Application Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Application Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Application Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Cloud Application Administrator | Notification_Admin_Admin_Eligibility | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Cloud Application Administrator | Notification_Admin_Admin_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
Cloud Application Administrator | Notification_Admin_EndUser_Assignment | Additional Recipients: Current=[sezai@rnkondagmail.onmicrosoft.com] -> Desired=[]
====================================================================================================
------------------- CURRENT STATE OF PIM SETTINGS FOR HIGHLY PRIVILEGED ROLES --------------------
====================================================================================================
------------- Current State of Pim Settings For Highly Privileged Roles Before Changes --------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Approval_EndUser_Assignment: Approval Configuration: True
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: User Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: [sezai@rnkondagmail.onmicrosoft.com]
====================================================================================================
DRIFT DETECTED: THE CURRENT STATE DOES NOT ALIGN WITH THE DESIRED STATE FOR SOME RULES OF SOME HIGHLY PRIVILEGED ROLES
====================================================================================================
UPDATING PIM SETTINGS TO MATCH THE DESIRED STATE FOR THE 4 TARGET RULES.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'Global Administrator'.

Successfully updated rule Notification_Admin_Admin_Eligibility for role Global Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'Global Administrator'.
Id
--
Notification_Admin_Admin_Eligibility
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role Global Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'Global Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role Global Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'Privileged Role Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role Privileged Role Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'Privileged Role Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role Privileged Role Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'Privileged Role Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role Privileged Role Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'User Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role User Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'User Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role User Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'User Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role User Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'SharePoint Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role SharePoint Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'SharePoint Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role SharePoint Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'SharePoint Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role SharePoint Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'Exchange Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role Exchange Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'Exchange Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role Exchange Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'Exchange Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role Exchange Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'Hybrid Identity Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role Hybrid Identity Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'Hybrid Identity Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role Hybrid Identity Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'Hybrid Identity Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role Hybrid Identity Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'Application Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role Application Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'Application Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role Application Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'Application Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role Application Administrator.
Processing rule 'Notification_Admin_Admin_Eligibility' for role 'Cloud Application Administrator'.
Notification_Admin_Admin_Eligibility
Successfully updated rule Notification_Admin_Admin_Eligibility for role Cloud Application Administrator.
Processing rule 'Notification_Admin_Admin_Assignment' for role 'Cloud Application Administrator'.
Notification_Admin_Admin_Assignment
Successfully updated rule Notification_Admin_Admin_Assignment for role Cloud Application Administrator.
Processing rule 'Notification_Admin_EndUser_Assignment' for role 'Cloud Application Administrator'.
Notification_Admin_EndUser_Assignme…
Successfully updated rule Notification_Admin_EndUser_Assignment for role Cloud Application Administrator.
====================================================================================================
Performing post-configuration drift detection.
====================================================================================================
====================================================================================================
Evaluating role: Global Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Global Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the Global Administrator role is as desired.
The rule to require Approval upon activation for role Global Administrator is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Global Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the Global Administrator role is as desired.
====================================================================================================
Evaluating role: Privileged Role Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the Privileged Role Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Privileged Role Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the Privileged Role Administrator role is as desired.
====================================================================================================
Evaluating role: User Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the User Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the User Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the User Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the User Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
User Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the User Administrator role is as desired.
====================================================================================================
Evaluating role: SharePoint Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the SharePoint Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
SharePoint Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the SharePoint Administrator role is as desired.
====================================================================================================
Evaluating role: Exchange Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the Exchange Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Exchange Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the Exchange Administrator role is as desired.
====================================================================================================
Evaluating role: Hybrid Identity Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the Hybrid Identity Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Hybrid Identity Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the Hybrid Identity Administrator role is as desired.
====================================================================================================
Evaluating role: Application Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the Application Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Application Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the Application Administrator role is as desired.
====================================================================================================
Evaluating role: Cloud Application Administrator
====================================================================================================
Sending notifications to default recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_Admin_Eligibility rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_Admin_Assignment rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to additional recipients  for Notification_Admin_Admin_Assignment rule when eligible members activate the Cloud Application Administrator role is as desired.
Sending notifications to default recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the 
Cloud Application Administrator role is as desired.
Sending notifications to additional recipients for Notification_Admin_EndUser_Assignment rule when eligible members activate the Cloud Application Administrator role is as desired.
====================================================================================================
DRIFT SUMMARY:
Global Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Global Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Global Administrator | Approval_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Global Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Privileged Role Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
User Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.        
SharePoint Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
SharePoint Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.    
SharePoint Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.  
Exchange Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.     
Exchange Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.      
Exchange Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.    
Hybrid Identity Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Hybrid Identity Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.  
Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary. 
Cloud Application Administrator | Notification_Admin_Admin_Eligibility | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_Admin_Assignment | Setting is configured as desired. No change is necessary.
Cloud Application Administrator | Notification_Admin_EndUser_Assignment | Setting is configured as desired. No change is necessary.
====================================================================================================
------------------- CURRENT STATE OF PIM SETTINGS FOR HIGHLY PRIVILEGED ROLES --------------------
====================================================================================================
------------- Current State of Pim Settings For Highly Privileged Roles After Changes ---------------
====================================================================================================
Role: Global Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Approval_EndUser_Assignment: Approval Configuration: True
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: Privileged Role Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: User Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: SharePoint Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: Exchange Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: Hybrid Identity Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: Application Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Role: Cloud Application Administrator
Notification_Admin_Admin_Eligibility: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_Admin_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
Notification_Admin_EndUser_Assignment: Default Alert Recipient Configuration: True
 Additional Recipients: []
====================================================================================================
NO DRIFT DETECTED: THE CURRENT STATE ALIGNS WITH THE DESIRED STATE FOR ALL HIGHLY PRIVILEGED ROLES
====================================================================================================
PIM SETTINGS ARE CONFIGURED AS DESIRED. THE CHANGE WAS SUCCESSFUL.

Key   : ExitCode
Value : 3
Name  : ExitCode


Key   : ExitLogs
Value : Change was successful.
Name  : ExitLogs
